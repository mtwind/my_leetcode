# %% [markdown]
# # **Expected Transitions to Reach Next State**
#
# ## Bullish or Bearish
# ![image.png](attachment:image.png)
# <br>
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # **Rate Questions**
#
# ## **Bouncy Castle**
# ![image-6.png](attachment:image-6.png)
# <br>
# ![image-7.png](attachment:image-7.png)
#
# # Expected Return Dice
# ![image-8.png](attachment:image-8.png)
#
# # Business Unit Profit
#
# ![image.png](attachment:image.png)
#
# # Trading Frequency and Loss
#
# ![image-2.png](attachment:image-2.png)
# ![image-14.png](attachment:image-14.png)
#
#
# # Probability of rolling Consecutive evens or odds
#
# ![image-3.png](attachment:image-3.png)
# ![image-15.png](attachment:image-15.png)
#
# # **Expected Return Per Roll - 3 dice**
#
# ## $28, $8, -$8
# ![image-4.png](attachment:image-4.png)
# <br>
# ![image-5.png](attachment:image-5.png)
#
#
# # **Chess Board Combinations**
# ![image-11.png](attachment:image-11.png)
#
# # Bayes Theorem Algorithm
# ![image-12.png](attachment:image-12.png) <br>
# ![image-13.png](attachment:image-13.png)
#
# # Song Skipping
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)
#
# To determine the probability of an event happening y times out x
#     -
